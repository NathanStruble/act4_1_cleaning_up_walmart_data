# %% [markdown]
# # Activity 4.1 - Cleaning Walmart Data the OpenRefine Way
#
# In this activity, you will practice what you learned in Lecture 4.5 by cleaning up a data set containing information on various Walmart locations.

# %%
import pandas as pd
from dfply import *

# %% [markdown]
# #### Initial Tasks
#
# 1. Try to read in the `./data/Walmart_United_States_&_Canada.csv` file and verify that you get an encoding error.  This means that the [character encoding](https://en.wikipedia.org/wiki/Character_encoding) isn't the default of `utf-8`.  The easiest way to fix this is to open and save the file in Visual Studio Code.

# %%
walmart = pd.read_csv("./data/Walmart_United_States_&_Canada.csv")

# %% [markdown]
# 2. Read in the data to verify that the encoding is fixed, but that there are two more problems.  What are they?

# %%
walmart
# Out:
#       -114.005671  51.262567      Walmart Supercentre; #1050,  \
# 0     -111.900542  50.577939      Walmart Supercentre; #3658,
# 1     -114.039133  51.107253      Walmart Supercentre; #3013,
# 2     -114.138488  51.040871  Walmart Supercentre; #3009,Gas,
# 3     -114.028603  50.930551                  Walmart; #1144,
# 4     -113.911590  51.040090      Walmart Supercentre; #1136,
# ...           ...        ...                              ...
# 6810  -107.209281  41.792084  Walmart Supercenter; #4471,Gas,
# 6811  -108.379227  43.042858      Walmart Supercenter; #1457,
# 6812  -109.251020  41.579761      Walmart Supercenter; #1461,
# 6813  -106.940967  44.779474      Walmart Supercenter; #1508,
# 6814  -135.069300  60.733253      Walmart Supercentre; #3191,
#
#      2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 0        917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 1     1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(40...
# 2     1212 37 St SW,Calgary ,(NOP),AB T3C 1S3,(403) ...
# 3     1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,...
# 4     255 E Hills Blvd SE,Calgary ,AB T2A 4X7,(403) ...
# ...                                                 ...
# 6810  2390 E Cedar St; I-80 Exit 214,Rawlins,WY,8230...
# 6811  1733 N Federal Blvd,Riverton,WY,82501 ,,(307) ...
# 6812  201 Gateway Blvd; I-80 Exit 102,Rock Springs,W...
# 6813  1695 Coffeen Ave; I-90 Exit 25,Sheridan,WY,828...
# 6814  9021 Quartz Rd,Whitehorse ,YT Y1A 4P9,(867) 66...
#
# [6815 rows x 4 columns]

# %% [markdown]
# No headers, some columns are combined

# %% [markdown]
# <font color="blue"> Your thoughts here </font>

# %% [markdown]
# 3. Take another look at the file in VS Code and determine solutions to the two/three issues, then read in the data correctly by passing `pd.read_csv` the correct defaults for this data. **Note.** Leave the `"` in place for now, as they serve an important role here!

# %% [markdown]
# Add column headers to first row in dataset.

# %%
help(pd.read_csv) # This might help!

# %% [markdown]
# <font color="blue"> Your thoughts here </font>

# %%
walmart = pd.read_csv("./data/Walmart_United_States_&_Canada.csv", names=["Latitude", "Longitude", "Store_Info", "Additional_Info", "Phone", "Province/State", "Fuel", "Address"])
walmart
# Out:
#         Latitude  Longitude                       Store_Info  \
# 0    -114.005671  51.262567      Walmart Supercentre; #1050,
# 1    -111.900542  50.577939      Walmart Supercentre; #3658,
# 2    -114.039133  51.107253      Walmart Supercentre; #3013,
# 3    -114.138488  51.040871  Walmart Supercentre; #3009,Gas,
# 4    -114.028603  50.930551                  Walmart; #1144,
# ...          ...        ...                              ...
# 6811 -107.209281  41.792084  Walmart Supercenter; #4471,Gas,
# 6812 -108.379227  43.042858      Walmart Supercenter; #1457,
# 6813 -109.251020  41.579761      Walmart Supercenter; #1461,
# 6814 -106.940967  44.779474      Walmart Supercenter; #1508,
# 6815 -135.069300  60.733253      Walmart Supercentre; #3191,
#
#                                         Additional_Info  Phone  \
# 0     2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-...    NaN
# 1        917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111    NaN
# 2     1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(40...    NaN
# 3     1212 37 St SW,Calgary ,(NOP),AB T3C 1S3,(403) ...    NaN
# 4     1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,...    NaN
# ...                                                 ...    ...
# 6811  2390 E Cedar St; I-80 Exit 214,Rawlins,WY,8230...    NaN
# 6812  1733 N Federal Blvd,Riverton,WY,82501 ,,(307) ...    NaN
# 6813  201 Gateway Blvd; I-80 Exit 102,Rock Springs,W...    NaN
# 6814  1695 Coffeen Ave; I-90 Exit 25,Sheridan,WY,828...    NaN
# 6815  9021 Quartz Rd,Whitehorse ,YT Y1A 4P9,(867) 66...    NaN
#
#       Province/State  Fuel  Address
# 0                NaN   NaN      NaN
# 1                NaN   NaN      NaN
# 2                NaN   NaN      NaN
# 3                NaN   NaN      NaN
# 4                NaN   NaN      NaN
# ...              ...   ...      ...
# 6811             NaN   NaN      NaN
# 6812             NaN   NaN      NaN
# 6813             NaN   NaN      NaN
# 6814             NaN   NaN      NaN
# 6815             NaN   NaN      NaN
#
# [6816 rows x 8 columns]

# %% [markdown]
# ## Cleaning up the store information.
#
# As hinted at above, the presence of the `"` meant the two of the columns--one containing the store type/number and the other contain the address/phone number--are combined together.  This was done because some of these entries have a different number of variables.  For example, the store type/number column sometimes occasionally `Gas`.
#
# In this part of the activity, you should apply the iterative OpenRefine approach to separate the information in the store column.
#
# **Warning!** There is one entry that doesn't follow the same pattern as the rest.  You won't find this entry unless you carefully define/fix/eliminate patterns.

# %%
from more_dfply import case_when, ifelse
from more_dfply.facets import text_facet, text_filter

# Your code here.

# %%
(walmart
>> filter_by(~text_filter(X.Store_Info, "Gas/Diesel", regex=True))
>> filter_by(~text_filter(X.Store_Info, "Gas,", regex=True)))
# Out:
#         Latitude  Longitude                   Store_Info  \
# 0    -114.005671  51.262567  Walmart Supercentre; #1050,
# 1    -111.900542  50.577939  Walmart Supercentre; #3658,
# 2    -114.039133  51.107253  Walmart Supercentre; #3013,
# 4    -114.028603  50.930551              Walmart; #1144,
# 5    -113.911590  51.040090  Walmart Supercentre; #1136,
# ...          ...        ...                          ...
# 6810 -105.540295  41.302595  Walmart Supercenter; #1412,
# 6812 -108.379227  43.042858  Walmart Supercenter; #1457,
# 6813 -109.251020  41.579761  Walmart Supercenter; #1461,
# 6814 -106.940967  44.779474  Walmart Supercenter; #1508,
# 6815 -135.069300  60.733253  Walmart Supercentre; #3191,
#
#                                         Additional_Info  Phone  \
# 0     2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-...    NaN
# 1        917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111    NaN
# 2     1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(40...    NaN
# 4     1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,...    NaN
# 5     255 E Hills Blvd SE,Calgary ,AB T2A 4X7,(403) ...    NaN
# ...                                                 ...    ...
# 6810  4308 Grand Ave; I-80 Exit 316,Laramie,WY,82070...    NaN
# 6812  1733 N Federal Blvd,Riverton,WY,82501 ,,(307) ...    NaN
# 6813  201 Gateway Blvd; I-80 Exit 102,Rock Springs,W...    NaN
# 6814  1695 Coffeen Ave; I-90 Exit 25,Sheridan,WY,828...    NaN
# 6815  9021 Quartz Rd,Whitehorse ,YT Y1A 4P9,(867) 66...    NaN
#
#       Province/State  Fuel  Address
# 0                NaN   NaN      NaN
# 1                NaN   NaN      NaN
# 2                NaN   NaN      NaN
# 4                NaN   NaN      NaN
# 5                NaN   NaN      NaN
# ...              ...   ...      ...
# 6810             NaN   NaN      NaN
# 6812             NaN   NaN      NaN
# 6813             NaN   NaN      NaN
# 6814             NaN   NaN      NaN
# 6815             NaN   NaN      NaN
#
# [3842 rows x 8 columns]

# %%
(walmart
>> filter_by(~text_filter(X.Store_Info, "Walmart (Supercenter|Supercentre)?; #\d{4},", regex= True))
>> filter_by(~text_filter(X.Store_Info, "Walmart;", regex=True))
>> filter_by(~text_filter(X.Store_Info, "USA;", regex=True))
>> filter_by(~text_filter(X.Store_Info, "Club;", regex=True))
>> filter_by(~text_filter(X.Store_Info, "Mkt;", regex=True))
>> filter_by(~text_filter(X.Store_Info, "Clinic;", regex=True))
)
# Out:
# /home/nathan/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/more_dfply/facets.py:30: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return col.str.contains(pattern, case=case, regex=regex, na=na)
#         Latitude  Longitude                             Store_Info  \
# 192   -86.730200  34.756393      Walmart Pickup & Fuel; #5746,Gas,
# 429   -94.152051  36.280774                Wm Nbrhd Mkt,#0241,Gas,
# 1049 -104.966898  39.884508      Walmart Pickup & Fuel; #5915,Gas,
# 2743  -90.129059  30.001925                  Walmart Pickup;#9294,
# 4400  -81.743882  41.383342             Walmart Supercenter;#5082,
# 4619  -94.623953  35.798618  Walmart Supercenter;#0081,Gas/Diesel,
# 4830 -122.856085  42.366996             Walmart Supercenter;#5839,
# 5771 -106.576950  31.882690         Walmart Supercenter;#5717,Gas,
# 5815  -96.735142  33.127517  Walmart Supercenter; #020,Gas/Diesel,
# 5816  -96.736314  33.127459         Walmart Supercenter;#0202,Gas,
# 5817  -96.886839  33.143145  Walmart Supercenter;#2463,Gas/Diesel,
# 5944  -95.767839  29.818438  Walmart Supercenter;#4512,Gas/Diesel,
# 6093  -95.222048  30.153130         Walmart Supercenter;#6579,Gas,
# 6135  -96.769302  33.054745         Walmart Fuel Center,#0997,Gas,
# 6156  -96.796902  33.221384  Walmart Supercenter,#6300,Gas/Diesel,
#
#                                         Additional_Info  Phone  \
# 192     7520 Hwy 72 W,Madison,AL,35758 ,,(256) 721-6402    NaN
# 429   4206 S Pleasant Crossing Blvd,Rogers,AR,72758 ...    NaN
# 1049  1650 E 104th Ave,Thornton,CO,80233 ,,(303) 280...    NaN
# 2743  615 Veterans Blvd,Metairie,LA,70005 ,,(504) 83...    NaN
# 4400  8303 W Ridgewood Dr,Parma,OH,44129 ,(NOP),(440...    NaN
# 4619     1893 Hwy 59,Stilwell,OK,74960 ,,(918) 696-3141    NaN
# 4830  3615 Crater Lake Hwy,Medford,OR,97504 ,(NOP),(...    NaN
# 5771  7831 Paseo Del Norte Blvd; I-10 Exit 8/9,El Pa...    NaN
# 5815     16066 Hwy 121,Frisco,TX,75035 ,,(469) 675-1684    NaN
# 5816     16066 Hwy 121,Frisco,TX,75035 ,,(469) 675-1684    NaN
# 5817  355 Stonebrook Pkwy,Frisco,TX,75034 ,,(972) 98...    NaN
# 5944  22850 Morton Ranch Rd; I-10 Exit 743,Katy,TX,7...    NaN
# 6093   20310 Hwy 59,New Caney,TX,77357 ,,(281) 306-7101    NaN
# 6135                       6040 Coit Rd,Plano,TX,75023,    NaN
# 6156  500 Richland Blvd,Prosper,TX,75078 ,,(972) 347...    NaN
#
#       Province/State  Fuel  Address
# 192              NaN   NaN      NaN
# 429              NaN   NaN      NaN
# 1049             NaN   NaN      NaN
# 2743             NaN   NaN      NaN
# 4400             NaN   NaN      NaN
# 4619             NaN   NaN      NaN
# 4830             NaN   NaN      NaN
# 5771             NaN   NaN      NaN
# 5815             NaN   NaN      NaN
# 5816             NaN   NaN      NaN
# 5817             NaN   NaN      NaN
# 5944             NaN   NaN      NaN
# 6093             NaN   NaN      NaN
# 6135             NaN   NaN      NaN
# 6156             NaN   NaN      NaN

# %%
(walmart
>> mutate(fuel = case_when((text_filter(X.Store_Info, "Gas/Diesel", regex=True), "Gas/Diesel"),
                           (text_filter(X.Store_Info, "Gas,", regex=True), "Gas"),
                           (True, "None")

))
>> mutate(store_type = case_when((text_filter(X.Store_Info, "Walmart (Supercenter | Supercentre)?; #\d{4},", regex=True), )
))
>> head()
)
# Out:
#      Latitude  Longitude                       Store_Info  \
# 0 -114.005671  51.262567      Walmart Supercentre; #1050,
# 1 -111.900542  50.577939      Walmart Supercentre; #3658,
# 2 -114.039133  51.107253      Walmart Supercentre; #3013,
# 3 -114.138488  51.040871  Walmart Supercentre; #3009,Gas,
# 4 -114.028603  50.930551                  Walmart; #1144,
#
#                                      Additional_Info  Phone  Province/State  \
# 0  2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-...    NaN             NaN
# 1     917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111    NaN             NaN
# 2  1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(40...    NaN             NaN
# 3  1212 37 St SW,Calgary ,(NOP),AB T3C 1S3,(403) ...    NaN             NaN
# 4  1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,...    NaN             NaN
#
#    Fuel  Address  fuel
# 0   NaN      NaN  None
# 1   NaN      NaN  None
# 2   NaN      NaN  None
# 3   NaN      NaN   Gas
# 4   NaN      NaN  None

# %% [markdown]
# ## Preview of Coming Attractions
#
# In this module's homework assignment, you will continue to clean up this data set.
